# %%
password = input("Enter the password: ")

if password == "admin123":
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Enter the password:  password
# Access Denied

# %%
age = int(input("user’s age :")) 
if age < 13: 
 print("Child") 
elif age >= 13 and age <= 19 : 
 print("Teen") 
elif age >= 20 and age <= 59 : 
 print("Adult") 
else: 
 print("Senior")
# Out:
# user’s age : 12
# Child

# %%
number=int(input("Read number :")) 
if number>0: 
 print(number , ":is Positive") 
else: 
 print(number , ":is Negative") 
if number>=10 and number<=50: 
 print(number , ":is inclusive between 10 and 50") 
else: 
 print(number , ":is NOT inclusive between 10 and 50")
# Out:
# Read number : 24
# 24 :is Positive
# 24 :is inclusive between 10 and 50

# %%
color = input("Enter a color (red, yellow, green): ")
if color != "":
    match color.lower():
        case "red":
            print("Stop")
        case "yellow":
            print("Get Ready")
        case "green":
            print("Go")
        case _:
            print("Invalid color")
else:
    print("No color entered")
# Out:
# Enter a color (red, yellow, green):  yellow
# Get Ready

# %%
print("Menu:")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = int(input("Choose an option (1-4): "))

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

match choice:
    case 1:
        print("Result =", num1 + num2)
    case 2:
        print("Result =", num1 - num2)
    case 3:
        print("Result =", num1 * num2)
    case 4:
        if num2 != 0:
            print("Result =", num1 / num2)
        else:
            print("Cannot divide by zero")
    case _:
        print("Invalid choice")
# Out:
# Menu:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Choose an option (1-4):  2
# Enter first number:  3
# Enter second number:  5
# Result = -2.0

# %%
score = int(input("Enter student score: "))
if score >= 50:
    print("Passed")
else:
    print("Failed")
if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
elif score >= 50:
    grade = "D"
else:
    grade = "F"

print("Grade:", grade)
match grade:
    case "A":
        print("Excellent")
    case "B":
        print("Very Good")
    case "C":
        print("Good")
    case "D":
        print("Pass")
    case "F":
        print("Fail")
# Out:
# Enter student score:  70
# Passed
# Grade: C
# Good
