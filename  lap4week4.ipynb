# %%
total = 0

for i in range(10):
    num = int(input("Enter a number: "))

    if num == 0:
        break

    if num < 0:
        continue

    if num % 2 == 0:
        total += num   

print("Final sum =", total)
# Out:
# Read 10 Numbers :
# Read number 5
# Read number 7
# Read number 8
# Read number 9
# Read number 8
# Read number 7
# Read number 4
# Read number 3
# Read number 2
# Read number 1
# Sum of Even Numbers =  22.0

# %%
num = int(input("Enter a number: "))

for i in range(1, 13):
    product = num * i

    if product > 50:
        break

    if product % 3 == 0:
        continue

    print(f"{num} x {i} = {product}")
# Out:
# Enter a number:  20
# 20 x 1 = 20
# 20 x 2 = 40

# %%
secret_number = 7  
attempts = 0

while True:
    guess = int(input("Guess a number between 1 and 20: "))

    if guess < 1 or guess > 20:
        print("Invalid guess! Try again.")
        continue

    attempts += 1

    if guess == secret_number:
        print("Correct! ")
        break
    else:
        print("Wrong guess!")

print("Number of valid attempts:", attempts)
# Out:
# Guess a number between 1 and 20:  7
# Correct!
# Number of valid attempts: 1

# %%
n = int(input("Enter a number: "))
count = 0

for i in range(1, n + 1):

    if i > 50:
        break

    if i % 8 == 0:
        continue

    if i % 4 == 0:
        count += 1

print("Count =", count)
# Out:
# Enter a number:  22
# Count = 3

# %%
for i in range(1, 6):
    for j in range(1, i + 1):

        if j == 3:
            continue

        if i * j > 6:
            break

        print(j, end=" ")

    print()
# Out:
# 1
# 1 2
# 1 2
# 1
# 1
